# %%
import pandas as pd

# %%
df = pd.read_csv('./titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pasajeros = df.groupby('Embarked').count()
pasajeros
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                 168       168     168   168  168  130    168    168     168
# Q                  77        77      77    77   77   28     77     77      77
# S                 644       644     644   644  644  554    644    644     644
#
#           Fare  Cabin
# Embarked
# C          168     69
# Q           77      4
# S          644    129

# %%
pasajeros = df.groupby('Embarked').agg(
    {
        'PassengerId' : 'count'
    }
)
pasajeros
# Out:
#           PassengerId
# Embarked
# C                 168
# Q                  77
# S                 644

# %%
pasajeros.plot.bar(
    y = 'PassengerId',
    width = 0.4,
    title = 'Numero de pasajeros por Embarked',
    legend = False
)
# Out:
# <Axes: title={'center': 'Numero de pasajeros por Embarked'}, xlabel='Embarked'>

# %%
import seaborn as sns

# %%
sns.barplot(
    pasajeros, 
    x='Embarked',
    y='PassengerId',
    width = 0.2
).set(
    title='Numero de pasajeros por Embarked',
)
# Out:
# [Text(0.5, 1.0, 'Numero de pasajeros por Embarked')]

# %%
import matplotlib.pyplot as plt

# %%
pasajeros2 = pasajeros.reset_index()
pasajeros2
# Out:
#   Embarked  PassengerId
# 0        C          168
# 1        Q           77
# 2        S          644

# %%
plt.barh(
    pasajeros2['Embarked'],
    pasajeros2['PassengerId']
)
plt.title('Numero de pasajeros por Embarked')
# Out:
# Text(0.5, 1.0, 'Numero de pasajeros por Embarked')
